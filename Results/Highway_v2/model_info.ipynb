# %%
import torch

state_dict = torch.load('eurosat_diffusion_model.pth', map_location='cpu')
for key in state_dict.keys():
    print(key)

state_dict = torch.load('eurosat_diffusion_model.pth', map_location='cpu')
total_params = sum(p.numel() for p in state_dict.values())

print(f"Total Parameters: {total_params:,}")
# Out:
# time_mlp.1.weight
# time_mlp.1.bias
# inc.weight
# inc.bias
# down1.mlp.1.weight
# down1.mlp.1.bias
# down1.conv1.weight
# down1.conv1.bias
# down1.norm1.weight
# down1.norm1.bias
# down1.conv2.weight
# down1.conv2.bias
# down1.norm2.weight
# down1.norm2.bias
# down1.shortcut.weight
# down1.shortcut.bias
# down_conv.weight
# down_conv.bias
# down2_block.mlp.1.weight
# down2_block.mlp.1.bias
# down2_block.conv1.weight
# down2_block.conv1.bias
# down2_block.norm1.weight
# down2_block.norm1.bias
# down2_block.conv2.weight
# down2_block.conv2.bias
# down2_block.norm2.weight
# down2_block.norm2.bias
# down2_block.shortcut.weight
# down2_block.shortcut.bias
# mid1.mlp.1.weight
# mid1.mlp.1.bias
# mid1.conv1.weight
# mid1.conv1.bias
# mid1.norm1.weight
# mid1.norm1.bias
# mid1.conv2.weight
# mid1.conv2.bias
# mid1.norm2.weight
# mid1.norm2.bias
# attn.norm.weight
# attn.norm.bias
# attn.qkv.weight
# attn.proj.weight
# attn.proj.bias
# mid2.mlp.1.weight
# mid2.mlp.1.bias
# mid2.conv1.weight
# ...
