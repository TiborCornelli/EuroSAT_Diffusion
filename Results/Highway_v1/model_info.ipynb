# %%
import torch

state_dict = torch.load('score_net_eurosat.pth', map_location='cpu')
for key in state_dict.keys():
    print(key)

state_dict = torch.load('score_net_eurosat.pth', map_location='cpu')
total_params = sum(p.numel() for p in state_dict.values())

print(f"Total Parameters: {total_params:,}")
# Out:
# time_embed.0.weight
# time_embed.0.bias
# time_embed.2.weight
# time_embed.2.bias
# inc.weight
# inc.bias
# down.0.net.0.weight
# down.0.net.0.bias
# down.0.net.1.weight
# down.0.net.1.bias
# down.0.net.3.weight
# down.0.net.3.bias
# down.0.net.4.weight
# down.0.net.4.bias
# down.1.weight
# down.1.bias
# mid.net.0.weight
# mid.net.0.bias
# mid.net.1.weight
# mid.net.1.bias
# mid.net.3.weight
# mid.net.3.bias
# mid.net.4.weight
# mid.net.4.bias
# up.0.weight
# up.0.bias
# up.1.net.0.weight
# up.1.net.0.bias
# up.1.net.1.weight
# up.1.net.1.bias
# up.1.net.3.weight
# up.1.net.3.bias
# up.1.net.4.weight
# up.1.net.4.bias
# out.weight
# out.bias
# Total Parameters: 2,615,939
